# %%
# %matplotlib inline 
#Импротируем необходимые функции
import numpy as np # работа с массивами и линейной алгеброй
import matplotlib.pyplot as plt # для отрисовки графиков
import pandas as pd # для чтения и работы с данными
from scipy.optimize import curve_fit

# %%
data = pd.read_csv('data/4B.csv', sep="\t", header=1)
x = data["V_a, B"]
y = data["I_k, mkA"]
plt.plot(x, y)
print(data)
plt.show()
# Out:
#     V_a, B  I_k, mkA
# 0     0.04       1.0
# 1     2.11       5.0
# 2     5.01      11.0
# 3    10.04      25.0
# 4    15.91      44.0
# 5    20.30      56.0
# 6    22.40      60.0
# 7    23.76      61.5
# 8    24.20      49.0
# 9    25.03      51.0
# 10   30.34      71.0
# 11   32.33      79.5
# 12   33.49      84.0
# 13   34.30      87.0
# 14   35.16      88.0
# 15   36.21      90.0
# 16   37.06      91.0
# 17   38.25      91.0
# 18   39.00      89.5
# 19   40.20      87.0
# 20   42.51      84.0
# 21   44.02      83.0
# 22   45.25      82.0
# 23   46.00      83.0
# 24   50.11      87.0
# 25   55.02      94.0
# 26   60.70     100.0

# %%
data = pd.read_csv('data/6B.csv', sep="\t", header=1)
x = data["V_a, B"]
y = data["I_k, mkA"]
plt.plot(x, y)
plt.show()

# %%
data = pd.read_csv('data/8B.csv', sep="\t", header=1)
x = data["V_a, B"]
y = data["I_k, mkA"]
plt.plot(x, y)
plt.show()
